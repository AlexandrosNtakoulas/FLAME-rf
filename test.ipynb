# %%
from pysemtools.rom.phy_pod_wrappers import pod_from_files
from mpi4py import MPI
# Communicator for parallelization
comm = MPI.COMM_WORLD

pod_from_files(comm, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 # Communicator for parallelization
#       4 comm = MPI.COMM_WORLD
# ----> 6 pod_from_files()
#
# TypeError: pod_from_files() missing 7 required positional arguments: 'comm', 'file_sequence', 'pod_fields', 'mass_matrix_fname', 'mass_matrix_key', 'k', and 'p'
