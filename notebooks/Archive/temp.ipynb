# %%
    "FDS_src_term",
    "FDS_diffusion_term",
    "FDS_diff_velocity_term",
    "gradT_normal",
    "H2_diffusion_total",
    "O2_diffusion_total",
    "H_diffusion_total",
    "total_heat_conduction",
    "u",
    "v",
    "abs_flame_prop_vel_normal",
    "strain_rate",
    "p",
    "phi_loc",
    "O",
    "H",
    "H2O",
    "HO2",
    "H2O2",
    "omega_O",
    "omega_H",
    "omega_HO2",
    "omega_H2O2",
    "omega_H2",
    "omega_O2",
    "OH",
    "omega_OH",
    "density_ratio_sigma",
    "omega_H2O",
    "O2",
    "H2"
