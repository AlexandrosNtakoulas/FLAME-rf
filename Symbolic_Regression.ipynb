# %%
import sys
sys.path.append("..")
from sklearn.preprocessing import StandardScaler
import pandas as pd
import sympy
from pysr import PySRRegressor

# %%
df = pd.read_csv("flame_front_po_post0.csv")
y = df["T"].to_numpy()
print(df.keys())
# Select meaningful physical variables
features = ['v', 'u', 'dudx', 'dudy', 'dvdx', 'dvdy', 'H2',
       'O2', 'H2O', 'H', 'O', 'OH', 'HO2', 'H2O2' ]
X = StandardScaler().fit_transform(df[features])
# Out:
# Index(['x', 'y', 'u', 'v', 'T', 'c', 'dudx', 'dudy', 'dvdx', 'dvdy', 'H2',
#        'O2', 'H2O', 'H', 'O', 'OH', 'HO2', 'H2O2', 'N2', 'omega_H2',
#        'omega_O2', 'omega_H2O', 'omega_H', 'omega_O', 'omega_OH', 'omega_HO2',
#        'omega_H2O2', 'omega_N2', 'Le_def'],
#       dtype='object')

# %%
default_pysr_params = dict(
    populations=30,
    model_selection="best",
)

model = PySRRegressor(
    niterations=30,
    binary_operators=["+", "*","/"],
    unary_operators=["cos", "exp", "sin"],
    **default_pysr_params,
)

model.fit(X, y)
# Out:
# C:\Users\alexp\Documents\Bachelor Thesis\Code\.venv\Lib\site-packages\pysr\sr.py:2811: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 2.730e+04
# Progress: 186 / 900 total iterations (20.667%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.635e-02  0.000e+00  y = 4.2147
# 4           4.882e-02  1.901e-01  y = cos(x₁₃) + 3.3947
# 5           1.938e-02  9.240e-01  y = (x₇ * -0.18811) + 4.2107
# 6           4.709e-03  1.415e+00  y = exp(x₈ * 0.073312) * 4.2042
# 24          3.558e-03  1.558e-02  y = exp((exp(sin(exp(cos((x₇ * 0.066822) + 1.4188)))) * co...
#                                       s(((0.29456 + x₁₂) + 1.7654) * -0.10092)) * (-0.67793 * co...
#                                       s(2.6335)))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.370e+04
# Progress: 395 / 900 total iterations (43.889%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.635e-02  0.000e+00  y = 4.2147
# 4           4.882e-02  1.901e-01  y = cos(x₁₃) + 3.3947
# 5           1.256e-02  1.358e+00  y = (x₇ + -16.358) / -3.8742
# 6           4.709e-03  9.809e-01  y = exp(x₈ * 0.073312) * 4.2042
# 10          1.072e-03  3.701e-01  y = ((x₉ * -0.11175) + 4.2055) * exp(x₇ * -0.070353)
# 12          1.072e-03  4.694e-05  y = (((x₉ + 1.325) * -0.11186) + 4.3535) * exp(x₇ * -0.070...
#                                       44)
# 15          3.728e-04  3.520e-01  y = ((x₉ + -4.0394) * -0.098955) + (sin(exp((x₇ + -0.15915...
#                                       ) * -0.11502)) * 4.4893)
# 17          3.553e-04  2.397e-02  y = (((x₉ + -0.089506) * -0.10303) + -0.47868) + (sin(exp(...
#                                       (x₇ + 0.078937) * -0.090759)) * 5.5976)
# 20          3.271e-04  2.765e-02  y = sin(exp((x₇ + -0.39495) * sin(0.017226)) * 2.5603) * (...
#                                       ((x₉ + (x₁₀ / 3.1)) * -0.13314) + 7.4915)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.440e+04
# Progress: 601 / 900 total iterations (66.778%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.635e-02  0.000e+00  y = 4.2147
# 4           4.882e-02  1.901e-01  y = cos(x₁₃) + 3.3947
# 5           1.230e-02  1.378e+00  y = (x₇ * -0.27212) + 4.2147
# 6           4.709e-03  9.604e-01  y = exp(x₈ * 0.073312) * 4.2042
# 9           3.323e-03  1.162e-01  y = (((x₆ + 0.22992) + x₇) * -0.15892) + 4.2512
# 10          1.072e-03  1.132e+00  y = ((x₉ * -0.11185) + 4.2053) * exp(x₇ * -0.070435)
# 11          3.619e-04  1.086e+00  y = (sin(exp(x₇ * -0.1019)) * 5.0148) + (x₉ * -0.10168)
# 15          3.466e-04  1.078e-02  y = (x₉ * -0.10324) + ((sin(exp((0.037092 + x₇) * -0.08555...
#                                       1)) * 5.937) + -0.7666)
# 20          3.271e-04  1.160e-02  y = sin(exp((x₇ + -0.39495) * sin(0.017226)) * 2.5603) * (...
#                                       ((x₉ + (x₁₀ / 3.1)) * -0.13314) + 7.4915)
# 22          3.065e-04  3.242e-02  y = (sin(exp((x₉ + x₇) * -0.10814)) * (exp((x₉ + 0.95746) ...
#                                       * -0.029786) * 4.8416)) + ((x₉ + 0.95063) / 3.7533)
# 24          1.831e-04  2.576e-01  y = ((x₉ + 0.36996) / 3.0502) + ((sin(exp((x₇ + x₉) * 0.01...
#                                       7653) * 2.5259) * 7.3678) * exp((x₉ + 0.81744) * -0.049189...
#                                       ))
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.380e+04
# Progress: 775 / 900 total iterations (86.111%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.635e-02  0.000e+00  y = 4.2147
# 4           4.882e-02  1.901e-01  y = cos(x₁₃) + 3.3947
# 5           1.230e-02  1.378e+00  y = (x₇ * -0.27212) + 4.2147
# 6           4.709e-03  9.604e-01  y = exp(x₈ * 0.073312) * 4.2042
# 7           3.323e-03  3.487e-01  y = ((x₆ + x₇) * -0.15892) + 4.2147
# 9           2.013e-03  2.507e-01  y = 4.2512 + (((x₁₂ + 0.22992) + x₇) * -0.15892)
# 10          1.072e-03  6.303e-01  y = ((x₉ * -0.11185) + 4.2053) * exp(x₇ * -0.070435)
# 11          3.619e-04  1.086e+00  y = (sin(exp(x₇ * -0.1019)) * 5.0148) + (x₉ * -0.10168)
# 13          3.619e-04  2.980e-08  y = (sin(exp(x₇ * -0.1019)) * 5.0148) + ((x₉ / -1.3113) * ...
#                                       0.13333)
# 15          3.466e-04  2.156e-02  y = (x₉ * -0.10324) + ((sin(exp((0.037092 + x₇) * -0.08555...
#                                       1)) * 5.937) + -0.7666)
# 18          2.827e-04  6.789e-02  y = (sin(exp(x₇ * 0.01962) * 2.4817) * 0.92836) * (sin(x₉ ...
#                                       + (x₉ * -1.1829)) + 7.4163)
# 24          1.831e-04  7.241e-02  y = ((x₉ + 0.36996) / 3.0502) + ((sin(exp((x₇ + x₉) * 0.01...
#                                       7653) * 2.5259) * 7.3678) * exp((x₉ + 0.81744) * -0.049189...
#                                       ))
# 26          1.766e-04  1.798e-02  y = (sin((x₉ * -1.155) + x₉) + 7.4163) * (sin((exp(sin((x₈...
#                                        + x₇) * -0.0066298)) * 2.475) * exp(x₇ * 0.019865)) * 0.9...
#                                       2054)
# 27          1.752e-04  8.120e-03  y = (sin((exp(sin(x₇ * 0.019774)) * exp(sin(x₈ + x₇) * -0....
#                                       0067312)) * 2.4765) * 0.9225) * (sin(x₉ + (x₉ * -1.1559)) ...
#                                       + 7.4165)
# 28          1.506e-04  1.516e-01  y = (sin((x₉ * -1.1534) + x₉) + 7.4231) * (sin((exp((x₈ + ...
#                                       x₇) * -0.0064264) * exp(sin((x₇ + 0.0073397) * 0.017938)))...
#                                        * 2.5192) * 0.97572)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           8.635e-02  0.000e+00  y = 4.2147
# 4           4.882e-02  1.901e-01  y = cos(x₁₃) + 3.3947
# 5           1.230e-02  1.378e+00  y = (x₇ * -0.27212) + 4.2147
# 6           4.709e-03  9.604e-01  y = exp(x₈ * 0.073312) * 4.2042
# 7           2.193e-03  7.644e-01  y = ((x₇ + x₁₂) * -0.1585) + 4.2281
# 9           2.012e-03  4.300e-02  y = (((x₇ + x₁₂) + 0.2194) * -0.1585) + 4.2495
# 10          1.072e-03  6.300e-01  y = exp(x₇ * -0.070438) * ((x₉ * -0.11185) + 4.2053)
# 11          3.619e-04  1.086e+00  y = ((x₉ * -0.020276) + sin(exp(x₇ * -0.1019))) * 5.0148
# 12          3.493e-04  3.540e-02  y = sin(x₉ * -0.10168) + (sin(exp(x₇ * -0.1019)) * 5.0148)
# 15          3.466e-04  2.572e-03  y = (x₉ * -0.10324) + ((sin(exp((0.037092 + x₇) * -0.08555...
#                                       1)) * 5.937) + -0.7666)
# 16          2.939e-04  1.649e-01  y = sin(exp(x₇ * 0.019587) * 2.4815) * (sin((x₉ * -1.169) ...
#                                       + x₉) + 6.8844)
# 18          1.809e-04  2.427e-01  y = sin(0.06369 + (exp(x₇ * 0.015649) * 2.5155)) * (exp((x...
#                                       ₉ * -1.2538) + x₉) + 6.887)
# 22          1.321e-04  7.863e-02  y = ((((x₉ * -1.134) + 7.387) + x₉) * sin(exp(x₇ * -0.1036...
#                                       9) * exp((x₈ + x₇) * 0.053174))) * 0.6787
# 25          9.615e-05  1.058e-01  y = ((9.9251 + sin((-1.2168 * x₉) + x₉)) * sin(exp(x₇ * 0....
#                                       012864) * (exp((x₈ + x₇) * -0.0051533) * 2.6534))) * 0.906...
#                                       16
# 27          9.179e-05  2.324e-02  y = ((9.9251 + sin((x₉ * -1.2168) + x₉)) * sin((exp((x₈ + ...
#                                       x₇) * -0.0051533) * 2.6534) * exp((x₇ + 0.0089763) * 0.012...
#                                       864))) * 0.90616
# 28          9.162e-05  1.799e-03  y = ((sin((x₉ * -1.2168) + x₉) + 9.9251) * sin((exp((x₈ + ...
#                                       x₇) * -0.0051533) * 2.6534) * exp(sin((x₇ + 0.0089763) * 0...
#                                       .012864)))) * 0.90616
# 29          9.119e-05  4.744e-03  y = (sin((x₉ * -1.2168) + x₉) + 9.9251) * (sin(exp(sin(x₈ ...
#                                       + x₇) * -0.0051533) * (2.6534 * exp(sin((x₇ + 0.0089763) *...
#                                        0.012864)))) * 0.90616)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# [ Info: Final population:
# [ Info: Results saved to:
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                           4.214702
# 	1         0.190104                               cos(x13) + 3.3946888
# 	2         1.378162                     (x7 * -0.27212188) + 4.2146926
# 	3         0.960414                   exp(x8 * 0.07331158) * 4.2041955
# 	4         0.764439             ((x7 + x12) * -0.15849625) + 4.2281337
# 	5         0.042996  (((x7 + x12) + 0.21939579) * -0.15849619) + 4....
# 	6         0.630001  exp(x7 * -0.07043849) * ((x9 * -0.11185004) + ...
# 	7         1.085620  ((x9 * -0.02027638) + sin(exp(x7 * -0.1018959)...
# 	8         0.035402  sin(x9 * -0.10167619) + (sin(exp(x7 * -0.10189...
# 	9         0.002572  (x9 * -0.10324182) + ((sin(exp((0.037091795 + ...
# 	10        0.164880  sin(exp(x7 * 0.019587297) * 2.4815412) * (sin(...
# 	11        0.242653  sin(0.063690335 + (exp(x7 * 0.01564862) * 2.51...
# 	12        0.078634  ((((x9 * -1.1340126) + 7.387026) + x9) * sin(e...
# 	13  >>>>  0.105828  ((9.925113 + sin((-1.216762 * x9) + x9)) * sin...
# 	14        0.023237  ((9.925113 + sin((x9 * -1.216762) + x9)) * sin...
# 	15        0.001799  ((sin((x9 * -1.216762) + x9) + 9.925113) * sin...
# 	16        0.004744  (sin((x9 * -1.216762) + x9) + 9.925113) * (sin...
#
# 	        loss  complexity
# 	0   0.086352           1
# 	1   0.048819           4
# 	2   0.012305           5
# 	3   0.004709           6
# 	4   0.002193           7
# 	5   0.002012           9
# 	6   0.001072          10
# 	7   0.000362          11
# 	8   0.000349          12
# 	9   0.000347          15
# 	10  0.000294          16
# 	11  0.000181          18
# 	12  0.000132          22
# 	13  0.000096          25
# 	14  0.000092          27
# 	15  0.000092          28
# 	16  0.000091          29
# ]
#   - outputs\20251028_203355_tqOaJA\hall_of_fame.csv

# %%
model.sympy()
# Out:
# (sin(-1.216762*x9 + x9) + 9.925113)*sin(exp(x7*0.012864303)*exp((x7 + x8)*(-0.0051532593))*2.6533554)*0.906157
