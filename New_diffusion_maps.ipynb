# %%
import diffusion_maps as dm
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import diffusion_maps as dm
#
# File ~\Documents\Bachelor Thesis\Code\.venv\Lib\site-packages\diffusion_maps\__init__.py:6
#       1 """Diffusion maps module.
#       2
#       3 """
#       5 from .diffusion_maps import *
# ----> 6 from .geometric_harmonics import *
#       7 from .plot import *
#       8 from .version import *
#
# File ~\Documents\Bachelor Thesis\Code\.venv\Lib\site-packages\diffusion_maps\geometric_harmonics.py:18
#      16 import numpy as np
#      17 import scipy.spatial
# ---> 18 from scipy.interpolate.interpnd import (NDInterpolatorBase,
#      19                                         _ndim_coords_from_arrays)
#      21 from diffusion_maps.diffusion_maps import DiffusionMaps
#      24 class GeometricHarmonicsInterpolator(NDInterpolatorBase):
#
# ...
